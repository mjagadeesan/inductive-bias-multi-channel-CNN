# %%
# Loading training and test data
import torch

data_tr = torch.load("training-test-data/training_data_nonlinear.txt")
target_tr = torch.load("training-test-data/training_targets_nonlinear.txt")
data_test = torch.load("training-test-data/test_data_nonlinear.txt")
target_test = torch.load("training-test-data/test_targets_nonlinear.txt")

num_samples = 512
num_samples_test = 100 # number of test samples
# new_dim1 = 28 * 1 # first dimension
# new_dim2 = 28 * 1 # second dimension
# old_dim = 28 # MNIST original dimension

new_dim1 = 32 # first dimension
new_dim2 = 32 # second dimension
old_dim = 32 # CIFAR original dimension

print(data_tr.shape)
# Out:
# torch.Size([512, 1, 32, 32])

# %%
import random
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import math
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib.pyplot as plt

# Two-layer linear convolutional neural network
output_channels = 1
class Net(nn.Module):
    def __init__(self, ker_size1, ker_size2, output_channels):
        super(Net, self).__init__()
        self.ker_size1 = ker_size1
        self.ker_size2 = ker_size2
        self.output_channels = output_channels
        self.conv1 = nn.Conv2d(1, output_channels, kernel_size=(self.ker_size1, self.ker_size2), bias=False) 
        self.fc1 = nn.Linear(int(new_dim1 * new_dim2 * output_channels), 1, bias=False)


    def forward(self, x):
        y1 = F.pad(x, (0,self.ker_size2-1,0,self.ker_size1-1), mode='circular') # Circular padding 
        y1 = self.conv1(y1)
        y1 = F.relu(y1) # ReLU activations
        y1 = y1.reshape(y1.size(0), -1)
        y1 = self.fc1(y1) 
        return y1

    def initialize(self, initialization_scale, ker_size1):
        nn.init.normal_(self.fc1.weight, mean=0.0, std=initialization_scale/np.sqrt(new_dim1))
        nn.init.normal_(self.conv1.weight, mean=0.0, std=initialization_scale/np.sqrt(ker_size1))


output = torch.zeros((num_samples, 1))
output = output.float()
output_test = torch.zeros((num_samples_test, 1))
output_test = output.float()


# Batch gradient descent
def train_minibatch(network, optimizer):
    minibatch_size = 512
    num_batch = int(num_samples/minibatch_size)
    for i in range(num_batch):
        network.train()
        optimizer.zero_grad()
        start_index = i * minibatch_size
        end_index = start_index + minibatch_size
        output = network(data_tr[start_index:end_index])
        loss = torch.sum(torch.exp(-1 * torch.mul(output.flatten(), target_tr[start_index:end_index]))) / minibatch_size
        loss.backward()
        optimizer.step()

# Evaluate training data loss
def train_eval(network):
    network.eval()
    train_loss = 0
    correct = 0
    with torch.no_grad():
        output = network(data_tr)
        train_loss = torch.sum(torch.exp(-1 * torch.mul(output.flatten(), target_tr)))
        pred = output.apply_(lambda x: 1 if x > 0 else -1)
        correct += pred.eq(target_tr.data.view_as(pred)).sum()
    train_loss /= num_samples
    print('\nTrain set: Avg. loss: {:.9f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
    train_loss, correct, num_samples,
    100. * correct / num_samples))
    return train_loss

def test(network):
    network.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        output_test = network(data_test)
        test_loss = torch.sum(torch.exp(-1 * torch.mul(output_test.flatten(), target_test)))
        pred = output_test.apply_(lambda x: 1 if x > 0 else -1)
        correct += pred.eq(target_test.data.view_as(pred)).sum()
    test_loss /= num_samples_test
    accuracy = 100. * correct / num_samples_test
    losses = test_loss
    return (accuracy, losses)


# Get the information about beta
def extract_info(network, show_photo): 

  # Compute beta for linear CNNs
    beta_test = np.zeros((new_dim1,new_dim2))
    for i in range(new_dim1):
        for j in range(new_dim2):
            tempimg = torch.zeros((1,1,new_dim1, new_dim2))
            tempimg[0,0,i,j]=1
            beta_test[i,j] = network(tempimg)  

  # Compute margin
    with torch.no_grad():
        network.eval()
        output_np = np.ndarray.flatten(network(data_tr).data.numpy())
        target_np = np.ndarray.flatten(target_tr.data.numpy())
        margins = [target_np[i] * output_np[i] for i in range(num_samples)]
        min_margin = min(margins) # get the minimum margin for any datapoint 


    # Compute R(beta)
    w1 = network.conv1.weight.detach().numpy()
    w2 = network.fc1.weight.detach().numpy()
    w1_norm_sq = np.sum(np.square(w1))
    w2_norm_sq = np.sum(np.square(w2))
    print(w1_norm_sq, w2_norm_sq)
    Rbeta = (np.sum(np.square(w1)) + np.sum(np.square(w2))) * np.sqrt(new_dim1 * new_dim2)


    # Normalize by margin 
    beta_test = beta_test / min_margin # normalize to have margin 1
    hat_beta = np.absolute(np.fft.fft2(beta_test,norm='ortho'))
    Rbeta = Rbeta / min_margin

    print("l2 norm: " + str(2 * np.sqrt(new_dim1 * new_dim2)* np.linalg.norm(beta_test, ord="fro")))
    print("l1 norm: " + str(2 * np.sum(hat_beta)))
    print("Rbeta: " + str(Rbeta))

    if show_photo:
        print("Time domain:")
        plt.imshow(np.absolute(beta_test), cmap='gray')
        plt.show()
        print("Frequency domain:")
        plt.imshow(np.absolute(hat_beta), cmap='gray', norm=LogNorm(vmin=0.0001, vmax=0.08))
        plt.show()
  
    return (Rbeta, beta_test)

# %%
# Train and extract info about beta
import seaborn as sns
n_epochs = 100000
learning_rate_start = 0.001
momentum = 0.3
initialization_scale = 0.01


from tqdm import tqdm_notebook as tqdm
def experiment(ker_size1, ker_size2, output_channels):
  # print(class1, class2)
    network = Net(ker_size1, ker_size2, output_channels)
    network.initialize(initialization_scale, ker_size1)
    optimizer =  optim.SGD(network.parameters(), lr=learning_rate_start, momentum=momentum)
    print("Before training:")
    train_eval(network)
    extract_info(network, False)
    # test()
    
    print("Start training:")
    for epoch in tqdm(range(1, n_epochs + 1)):
        train_minibatch(network, optimizer)
        if epoch % 100 == 0:
            loss = train_eval(network)
            if loss <= 0.000001: # stop at 10^-6 loss 
                break
            extract_info(network, False)
        # After enough epochs, change the learning rate to be higher to expedite convergence

        if epoch == 200 == 0:
            optimizer =  optim.SGD(network.parameters(), lr=0.005, momentum=momentum)
            print("Learning rate change")
              # optimizer =  optim.SGD(network.parameters(), lr=0.001, momentum=momentum)

        if epoch == 500:
            optimizer = optim.SGD(network.parameters(), lr=0.01, momentum=momentum)
            print("Learning rate change")
              # optimizer =  optim.SGD(network.parameters(), lr=0.001, momentum=momentum)

#         if epoch == 1000:
#             optimizer = optim.SGD(network.parameters(), lr=0.05, momentum=momentum)
              # print("Learning rate change")
#               optimizer =  optim.SGD(network.parameters(), lr=0.005, momentum=momentum)

#         if epoch == 2000:
#             optimizer = optim.SGD(network.parameters(), lr=0.1, momentum=momentum)
#               # optimizer =  optim.SGD(network.parameters(), lr=0.007, momentum=momentum)

#         if epoch == 1500:
#             optimizer = optim.SGD(network.parameters(), lr=0.5, momentum=momentum)

#         if epoch == 2000:
#             optimizer = optim.SGD(network.parameters(), lr=1, momentum=momentum)
#               # optimizer = optim.SGD(network.parameters(), lr=0.01, momentum=momentum)

#         if epoch == 3000:
#             optimizer = optim.SGD(network.parameters(), lr=2, momentum=momentum)
#               # optimizer = optim.SGD(network.parameters(), lr=0.01, momentum=momentum)

#         if epoch == 4000:
#             optimizer = optim.SGD(network.parameters(), lr=4, momentum=momentum)
#               # optimizer = optim.SGD(network.parameters(), lr=0.01, momentum=momentum)

#         if epoch == 4500:
#             optimizer = optim.SGD(network.parameters(), lr=10, momentum=momentum)

#         if epoch == 5000:
#             optimizer = optim.SGD(network.parameters(), lr=20, momentum=momentum)


        if epoch % 500 == 0:
            print(test(network))

    print("After training:")
    train_eval(network)
    (accuracy, losses) = test(network)
    print(accuracy, losses)

    (rk, beta) = extract_info(network, True)

    return (rk, beta)

# %%
# Run experiments and write data to a CSV

# Add weight decay (add that)

import pandas as pd


k_vals = [1, 3, 5, 8]
Cout = [1, 2, 3, 4]

for k in k_vals:
    pairs = []
    for c in Cout:
        pairs.append((k, c))

    betas = []
    rbetas = []

    for (k, output_channels) in pairs:
        print(k, output_channels)
        (Rbeta, beta) = experiment(k, k, output_channels)
        rbetas.append(Rbeta)
        betas.append(beta)

    # Write rbetas 
    name =  "experiments-data/" + str(k) + "rbeta" + str(Cout) + "nonlinear" + ".csv"
    pd.DataFrame(rbetas).to_csv(name, header=False, index=False)

    # Write betas
    for i in range(len(pairs)):
        beta = betas[i]
        beta = beta_array[j]
        name = "experiments-data/" + str(pairs[i]) + "nonlinear" + ".csv"
        print(str(pairs[i]))
        pd.DataFrame(beta).to_csv(name, header=False, index=False)
# Out:
# 1 1
# Before training:
#
# Train set: Avg. loss: 1.000011325, Accuracy: 246/512 (48%)
#
# 2.7761303e-05 0.0030443412
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -334.19076921372164
# Start training:
# <ipython-input-6-cd142e35a673>:21: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in tqdm(range(1, n_epochs + 1)):
#   0%|          | 0/100000 [00:00<?, ?it/s]
# Train set: Avg. loss: 1.000007749, Accuracy: 246/512 (48%)
#
# 2.5047044e-05 0.003041634
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -398.2904319503471
#
# Train set: Avg. loss: 1.000004649, Accuracy: 254/512 (50%)
#
# 2.3281247e-05 0.0030398753
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -473.63651234557483
#
# Train set: Avg. loss: 1.000001907, Accuracy: 255/512 (50%)
#
# 2.2355905e-05 0.0030389572
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -564.055995547812
#
# Train set: Avg. loss: 0.999999166, Accuracy: 267/512 (52%)
#
# 2.2206832e-05 0.0030388148
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -560.3979310611237
#
# Train set: Avg. loss: 0.999996483, Accuracy: 274/512 (54%)
#
# 2.2823411e-05 0.0030394383
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -531.4713825611327
# Learning rate change
# (tensor(45.), tensor(1.0000))
#
# Train set: Avg. loss: 0.999906540, Accuracy: 277/512 (54%)
#
# 0.00011342791 0.003130726
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -69.29439475724209
#
# Train set: Avg. loss: 0.998794556, Accuracy: 272/512 (53%)
#
# 0.0013418432 0.0043598013
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -10.116316854637187
#
# Train set: Avg. loss: 0.988542080, Accuracy: 271/512 (53%)
#
# 0.014071368 0.017090626
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -5.563543654862764
#
# Train set: Avg. loss: 0.960832536, Accuracy: 297/512 (58%)
#
# 0.064010024 0.06709088
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -6.823623394441691
#
# Train set: Avg. loss: 0.934897661, Accuracy: 315/512 (62%)
#
# 0.14036477 0.14358115
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -10.368835196915787
# (tensor(65.), tensor(0.9320))
#
# Train set: Avg. loss: 0.919499934, Accuracy: 330/512 (64%)
#
# 0.20746201 0.21084201
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -12.149608778458697
#
# Train set: Avg. loss: 0.904328406, Accuracy: 337/512 (66%)
#
# 0.28024152 0.2838207
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -15.632463266923667
#
# Train set: Avg. loss: 0.886958718, Accuracy: 348/512 (68%)
#
# 0.3777893 0.3815586
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -20.74365671896207
#
# Train set: Avg. loss: 0.867039144, Accuracy: 361/512 (71%)
#
# 0.5082003 0.51213896
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -27.57817446021253
#
# Train set: Avg. loss: 0.844905317, Accuracy: 368/512 (72%)
#
# 0.6749408 0.6790278
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -36.106287555127544
# (tensor(63.), tensor(0.9957))
#
# Train set: Avg. loss: 0.821147561, Accuracy: 371/512 (72%)
#
# 0.87822664 0.882447
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -46.11914368925255
#
# Train set: Avg. loss: 0.796263635, Accuracy: 382/512 (75%)
#
# 1.1167789 1.121129
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -57.36981824140991
#
# Train set: Avg. loss: 0.770647705, Accuracy: 394/512 (77%)
#
# 1.3891973 1.3936756
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -69.74072330693221
#
# Train set: Avg. loss: 0.744626224, Accuracy: 396/512 (77%)
#
# 1.6941302 1.6987377
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -83.24195814166467
#
# Train set: Avg. loss: 0.718443573, Accuracy: 402/512 (79%)
#
# 2.030227 2.0349638
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -97.9451983629267
# (tensor(56.), tensor(1.2483))
#
# Train set: Avg. loss: 0.692265689, Accuracy: 409/512 (80%)
#
# 2.396264 2.4011314
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -113.95108829438695
#
# Train set: Avg. loss: 0.666201234, Accuracy: 420/512 (82%)
#
# 2.7912538 2.7962534
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -131.37762944009395
#
# Train set: Avg. loss: 0.640328526, Accuracy: 424/512 (83%)
#
# 3.214416 3.2195468
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -150.352060718039
#
# Train set: Avg. loss: 0.614722133, Accuracy: 429/512 (84%)
#
# 3.665029 3.6702902
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -171.00353182340675
#
# Train set: Avg. loss: 0.589466870, Accuracy: 434/512 (85%)
#
# 4.1422586 4.147647
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -193.45964440811667
# (tensor(55.), tensor(1.9055))
#
# Train set: Avg. loss: 0.564659238, Accuracy: 438/512 (86%)
#
# 4.6450105 4.6505203
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -217.8463051379689
#
# Train set: Avg. loss: 0.540399730, Accuracy: 447/512 (87%)
#
# 5.1718616 5.177493
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -244.29098527008594
#
# Train set: Avg. loss: 0.516782999, Accuracy: 453/512 (88%)
#
# 5.7210865 5.726831
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -272.92707777784784
#
# Train set: Avg. loss: 0.493890375, Accuracy: 464/512 (91%)
#
# 6.290707 6.2965536
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -303.8976244776807
#
# Train set: Avg. loss: 0.471786588, Accuracy: 468/512 (91%)
#
# 6.878579 6.8845253
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -337.3600878513832
# (tensor(52.), tensor(3.4353))
#
# Train set: Avg. loss: 0.450518042, Accuracy: 471/512 (92%)
#
# 7.4825068 7.4885464
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -373.4891075784964
#
# Train set: Avg. loss: 0.430114627, Accuracy: 476/512 (93%)
#
# 8.100301 8.106426
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -412.47983722516693
#
# Train set: Avg. loss: 0.410591543, Accuracy: 479/512 (94%)
#
# 8.72984 8.736045
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -454.55097482736187
#
# Train set: Avg. loss: 0.391951829, Accuracy: 482/512 (94%)
#
# 9.369105 9.375387
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -499.9465588177315
#
# Train set: Avg. loss: 0.374188900, Accuracy: 483/512 (94%)
#
# 10.016191 10.022564
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -548.938713630378
# (tensor(50.), tensor(7.0112))
#
# Train set: Avg. loss: 0.357287526, Accuracy: 487/512 (95%)
#
# 10.66938 10.675818
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -601.8314336671351
#
# Train set: Avg. loss: 0.341227114, Accuracy: 489/512 (96%)
#
# 11.327043 11.33354
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -658.965441955257
#
# Train set: Avg. loss: 0.325982124, Accuracy: 493/512 (96%)
#
# 11.987705 11.994251
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -720.7255863109766
#
# Train set: Avg. loss: 0.311524153, Accuracy: 495/512 (97%)
#
# 12.649978 12.656612
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -787.5453123500134
#
# Train set: Avg. loss: 0.297821343, Accuracy: 498/512 (97%)
#
# 13.312715 13.319411
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -859.9246562860745
# (tensor(49.), tensor(15.6705))
#
# Train set: Avg. loss: 0.284841061, Accuracy: 502/512 (98%)
#
# 13.974808 13.981554
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -938.4362702489036
#
# Train set: Avg. loss: 0.272549987, Accuracy: 502/512 (98%)
#
# 14.635271 14.642063
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -1023.73849233239
#
# Train set: Avg. loss: 0.260914296, Accuracy: 503/512 (98%)
#
# 15.293238 15.300071
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -1116.6053249012064
#
# Train set: Avg. loss: 0.249900728, Accuracy: 505/512 (99%)
#
# 15.947929 15.954802
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -1217.9434065655096
#
# Train set: Avg. loss: 0.239476368, Accuracy: 505/512 (99%)
#
# 16.598667 16.605576
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -1328.8119287207146
# (tensor(49.), tensor(38.7374))
#
# Train set: Avg. loss: 0.229609206, Accuracy: 506/512 (99%)
#
# 17.244862 17.251797
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -1450.4869415662226
#
# Train set: Avg. loss: 0.220268473, Accuracy: 507/512 (99%)
#
# 17.885979 17.892942
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -1584.466351544059
#
# Train set: Avg. loss: 0.211424410, Accuracy: 507/512 (99%)
#
# 18.521574 18.528568
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -1732.5807381537134
#
# Train set: Avg. loss: 0.203048617, Accuracy: 507/512 (99%)
#
# 19.151274 19.15828
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -1897.0500769250636
#
# Train set: Avg. loss: 0.195114121, Accuracy: 507/512 (99%)
#
# 19.77472 19.781754
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -2080.589608690762
# (tensor(48.), tensor(107.8216))
#
# Train set: Avg. loss: 0.187595278, Accuracy: 507/512 (99%)
#
# 20.391653 20.398708
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -2286.5609055714253
#
# Train set: Avg. loss: 0.180467606, Accuracy: 508/512 (99%)
#
# 21.00184 21.008923
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -2519.2152468521476
#
# Train set: Avg. loss: 0.173708275, Accuracy: 509/512 (99%)
#
# 21.605099 21.612198
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -2783.892785717817
#
# Train set: Avg. loss: 0.167295590, Accuracy: 509/512 (99%)
#
# 22.201271 22.208391
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -3087.557497470877
#
# Train set: Avg. loss: 0.161209017, Accuracy: 509/512 (99%)
#
# 22.790262 22.797379
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -3439.3115114396032
# (tensor(48.), tensor(332.7707))
#
# Train set: Avg. loss: 0.155429572, Accuracy: 510/512 (100%)
#
# 23.371946 23.379078
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -3851.397377044753
#
# Train set: Avg. loss: 0.149939090, Accuracy: 511/512 (100%)
#
# 23.946276 23.953426
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -4340.540532876661
#
# Train set: Avg. loss: 0.144720718, Accuracy: 511/512 (100%)
#
# 24.51322 24.52039
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -4930.355766302562
#
# Train set: Avg. loss: 0.139758438, Accuracy: 511/512 (100%)
#
# 25.072765 25.079947
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -5655.158124133365
# Train set: Avg. loss: 0.135037392, Accuracy: 511/512 (100%)
#
# 25.624908 25.632107
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -6566.9978942384605
# (tensor(48.), tensor(1081.5782))
#
# Train set: Avg. loss: 0.130543634, Accuracy: 511/512 (100%)
#
# 26.169666 26.176884
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -7748.682475776527
#
# Train set: Avg. loss: 0.126264006, Accuracy: 511/512 (100%)
#
# 26.707083 26.71431
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -9340.090815182064
#
# Train set: Avg. loss: 0.122186273, Accuracy: 511/512 (100%)
#
# 27.237188 27.244434
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -11598.643134381151
#
# Train set: Avg. loss: 0.118298873, Accuracy: 511/512 (100%)
#
# 27.76005 27.767311
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -15053.548532266306
#
# Train set: Avg. loss: 0.114591040, Accuracy: 511/512 (100%)
#
# 28.275726 28.283007
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -20996.62940231176
# (tensor(48.), tensor(3506.0588))
#
# Train set: Avg. loss: 0.111052617, Accuracy: 511/512 (100%)
#
# 28.784307 28.791595
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -33623.578888743854
#
# Train set: Avg. loss: 0.107674137, Accuracy: 511/512 (100%)
#
# 29.285864 29.293156
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: -78689.52576163977
#
# Train set: Avg. loss: 0.104446791, Accuracy: 512/512 (100%)
#
# 29.78047 29.787773
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 283695.7808530268
#
# Train set: Avg. loss: 0.101362199, Accuracy: 512/512 (100%)
#
# 30.268225 30.27554
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 52591.00280880697
#
# Train set: Avg. loss: 0.098412558, Accuracy: 512/512 (100%)
#
# 30.749216 30.756546
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 29579.387613092786
# (tensor(46.), tensor(10942.2666))
#
# Train set: Avg. loss: 0.095590509, Accuracy: 512/512 (100%)
#
# 31.223562 31.230904
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 20856.85898692729
#
# Train set: Avg. loss: 0.092889167, Accuracy: 512/512 (100%)
#
# 31.69136 31.698704
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 16267.385576676725
#
# Train set: Avg. loss: 0.090302140, Accuracy: 512/512 (100%)
#
# 32.1527 32.16005
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 13436.281137488268
#
# Train set: Avg. loss: 0.087823331, Accuracy: 512/512 (100%)
#
# 32.60769 32.615047
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 11515.785744917637
#
# Train set: Avg. loss: 0.085447058, Accuracy: 512/512 (100%)
#
# 33.056442 33.063805
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 10127.52752785652
# (tensor(45.), tensor(32335.0156))
#
# Train set: Avg. loss: 0.083167978, Accuracy: 512/512 (100%)
#
# 33.49906 33.506424
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 9077.307278944798
#
# Train set: Avg. loss: 0.080981053, Accuracy: 512/512 (100%)
#
# 33.93566 33.94302
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 8255.073368085414
#
# Train set: Avg. loss: 0.078881614, Accuracy: 512/512 (100%)
#
# 34.366333 34.37369
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 7593.797148209483
#
# Train set: Avg. loss: 0.076865181, Accuracy: 512/512 (100%)
#
# 34.791183 34.798546
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 7050.636326853512
#
# Train set: Avg. loss: 0.074927583, Accuracy: 512/512 (100%)
#
# 35.210323 35.217697
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 6596.392212470403
# (tensor(45.), tensor(89991.5312))
#
# Train set: Avg. loss: 0.073064893, Accuracy: 512/512 (100%)
#
# 35.623863 35.63124
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 6211.072850572354
#
# Train set: Avg. loss: 0.071273416, Accuracy: 512/512 (100%)
#
# 36.031906 36.039284
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 5880.019208535397
#
# Train set: Avg. loss: 0.069549635, Accuracy: 512/512 (100%)
#
# 36.43456 36.441933
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 5592.596829230361
#
# Train set: Avg. loss: 0.067890301, Accuracy: 512/512 (100%)
#
# 36.83191 36.83929
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 5340.643010728296
#
# Train set: Avg. loss: 0.066292308, Accuracy: 512/512 (100%)
#
# 37.22406 37.231453
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 5117.990360411621
# (tensor(45.), tensor(235964.))
#
# Train set: Avg. loss: 0.064752713, Accuracy: 512/512 (100%)
#
# 37.611134 37.61852
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 4919.887027033875
#
# Train set: Avg. loss: 0.063268796, Accuracy: 512/512 (100%)
#
# 37.99319 38.000595
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 4742.416241464573
#
# Train set: Avg. loss: 0.061837919, Accuracy: 512/512 (100%)
#
# 38.370358 38.377766
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 4582.539976715746
#
# Train set: Avg. loss: 0.060457613, Accuracy: 512/512 (100%)
#
# 38.742733 38.750134
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 4437.796316270941
#
# Train set: Avg. loss: 0.059125591, Accuracy: 512/512 (100%)
#
# 39.110394 39.11779
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 4306.102539095742
# (tensor(45.), tensor(584628.9375))
#
# Train set: Avg. loss: 0.057839662, Accuracy: 512/512 (100%)
#
# 39.473415 39.480827
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 4185.791124765668
#
# Train set: Avg. loss: 0.056597725, Accuracy: 512/512 (100%)
#
# 39.831917 39.839333
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 4075.4150497703
#
# Train set: Avg. loss: 0.055397838, Accuracy: 512/512 (100%)
#
# 40.18597 40.193405
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3973.8641023742616
#
# Train set: Avg. loss: 0.054238085, Accuracy: 512/512 (100%)
#
# 40.535686 40.543114
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3880.0342714238295
#
# Train set: Avg. loss: 0.053116776, Accuracy: 512/512 (100%)
#
# 40.881115 40.888546
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3793.1254396248532
# (tensor(45.), tensor(1374027.))
#
# Train set: Avg. loss: 0.052032180, Accuracy: 512/512 (100%)
#
# 41.222378 41.229794
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3712.3991616146163
#
# Train set: Avg. loss: 0.050982773, Accuracy: 512/512 (100%)
#
# 41.559513 41.566936
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3637.211097607411
#
# Train set: Avg. loss: 0.049967032, Accuracy: 512/512 (100%)
#
# 41.892635 41.900047
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3567.0059430736137
#
# Train set: Avg. loss: 0.048983552, Accuracy: 512/512 (100%)
#
# 42.221786 42.229206
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3501.316787868416
#
# Train set: Avg. loss: 0.048030961, Accuracy: 512/512 (100%)
#
# 42.54707 42.554493
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3439.721394976538
# (tensor(44.), tensor(3076042.5000))
#
# Train set: Avg. loss: 0.047107983, Accuracy: 512/512 (100%)
#
# 42.86856 42.875977
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3381.8106728101934
#
# Train set: Avg. loss: 0.046213396, Accuracy: 512/512 (100%)
#
# 43.18633 43.193733
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3327.3168748798216
#
# Train set: Avg. loss: 0.045346044, Accuracy: 512/512 (100%)
#
# 43.500443 43.507835
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3275.91486363134
#
# Train set: Avg. loss: 0.044504873, Accuracy: 512/512 (100%)
#
# 43.810947 43.818348
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3227.363934015975
#
# Train set: Avg. loss: 0.043688774, Accuracy: 512/512 (100%)
#
# 44.117947 44.125343
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3181.4090866601123
# (tensor(44.), tensor(6585929.))
#
# Train set: Avg. loss: 0.042896796, Accuracy: 512/512 (100%)
#
# 44.421494 44.42888
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3137.878826407103
#
# Train set: Avg. loss: 0.042127974, Accuracy: 512/512 (100%)
#
# 44.72164 44.729027
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3096.550598967186
#
# Train set: Avg. loss: 0.041381422, Accuracy: 512/512 (100%)
#
# 45.018463 45.025852
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3057.2828141624886
#
# Train set: Avg. loss: 0.040656283, Accuracy: 512/512 (100%)
#
# 45.312016 45.319412
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 3019.94182928228
#
# Train set: Avg. loss: 0.039951712, Accuracy: 512/512 (100%)
#
# 45.602375 45.60977
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2984.345495357577
# (tensor(44.), tensor(13536330.))
#
# Train set: Avg. loss: 0.039266963, Accuracy: 512/512 (100%)
#
# 45.88958 45.896988
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2950.4009886253007
#
# Train set: Avg. loss: 0.038601246, Accuracy: 512/512 (100%)
#
# 46.173706 46.181114
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2917.986689315671
#
# Train set: Avg. loss: 0.037953898, Accuracy: 512/512 (100%)
#
# 46.4548 46.46221
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2887.0133765397673
#
# Train set: Avg. loss: 0.037324220, Accuracy: 512/512 (100%)
#
# 46.73292 46.740334
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2857.374256234195
#
# Train set: Avg. loss: 0.036711566, Accuracy: 512/512 (100%)
#
# 47.00812 47.015533
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2828.9862395717396
# (tensor(44.), tensor(26800674.))
#
# Train set: Avg. loss: 0.036115333, Accuracy: 512/512 (100%)
#
# 47.280445 47.287865
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2801.7707141624164
#
# Train set: Avg. loss: 0.035534907, Accuracy: 512/512 (100%)
#
# 47.54996 47.55738
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2775.669230454776
#
# Train set: Avg. loss: 0.034969747, Accuracy: 512/512 (100%)
#
# 47.81671 47.824127
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2750.5983799862606
# Train set: Avg. loss: 0.034419309, Accuracy: 512/512 (100%)
#
# 48.080734 48.08816
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2726.5014052256865
#
# Train set: Avg. loss: 0.033883065, Accuracy: 512/512 (100%)
#
# 48.342094 48.349518
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2703.317791465228
# (tensor(44.), tensor(51275904.))
#
# Train set: Avg. loss: 0.033360526, Accuracy: 512/512 (100%)
#
# 48.600834 48.608257
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2681.00888519928
#
# Train set: Avg. loss: 0.032851230, Accuracy: 512/512 (100%)
#
# 48.857 48.864418
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2659.520041073083
#
# Train set: Avg. loss: 0.032354720, Accuracy: 512/512 (100%)
#
# 49.11062 49.118042
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2638.800462749839
#
# Train set: Avg. loss: 0.031870566, Accuracy: 512/512 (100%)
#
# 49.361748 49.36918
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2618.8048560209168
#
# Train set: Avg. loss: 0.031398349, Accuracy: 512/512 (100%)
#
# 49.610443 49.61787
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2599.5282147453777
# (tensor(44.), tensor(95066616.))
#
# Train set: Avg. loss: 0.030937674, Accuracy: 512/512 (100%)
#
# 49.856716 49.86416
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2580.888815699402
#
# Train set: Avg. loss: 0.030488130, Accuracy: 512/512 (100%)
#
# 50.10066 50.108078
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2562.886880976908
#
# Train set: Avg. loss: 0.030049413, Accuracy: 512/512 (100%)
#
# 50.34225 50.349678
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2545.4705634840066
#
# Train set: Avg. loss: 0.029621132, Accuracy: 512/512 (100%)
#
# 50.581554 50.58899
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2528.6194264998435
#
# Train set: Avg. loss: 0.029202944, Accuracy: 512/512 (100%)
#
# 50.81861 50.826057
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2512.3007251180784
# (tensor(44.), tensor(1.7124e+08))
#
# Train set: Avg. loss: 0.028794544, Accuracy: 512/512 (100%)
#
# 51.05347 51.060913
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2496.5117776623333
#
# Train set: Avg. loss: 0.028395612, Accuracy: 512/512 (100%)
#
# 51.28615 51.29359
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2481.191050712963
#
# Train set: Avg. loss: 0.028005853, Accuracy: 512/512 (100%)
#
# 51.51671 51.524136
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2466.339236417746
#
# Train set: Avg. loss: 0.027624967, Accuracy: 512/512 (100%)
#
# 51.745167 51.752575
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2451.94581344871
#
# Train set: Avg. loss: 0.027252721, Accuracy: 512/512 (100%)
#
# 51.97152 51.97895
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2437.9560626089387
# (tensor(44.), tensor(3.0033e+08))
#
# Train set: Avg. loss: 0.026888814, Accuracy: 512/512 (100%)
#
# 52.19585 52.203285
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2424.3870516328375
#
# Train set: Avg. loss: 0.026532976, Accuracy: 512/512 (100%)
#
# 52.418205 52.42562
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2411.184631364745
#
# Train set: Avg. loss: 0.026185021, Accuracy: 512/512 (100%)
#
# 52.63855 52.64598
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2398.376234316668
#
# Train set: Avg. loss: 0.025844643, Accuracy: 512/512 (100%)
#
# 52.85699 52.8644
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2385.9064512207487
#
# Train set: Avg. loss: 0.025511675, Accuracy: 512/512 (100%)
#
# 53.073494 53.080914
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2373.7816257296963
# (tensor(44.), tensor(5.1398e+08))
#
# Train set: Avg. loss: 0.025185874, Accuracy: 512/512 (100%)
#
# 53.288116 53.295544
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2361.9933116508505
#
# Train set: Avg. loss: 0.024867013, Accuracy: 512/512 (100%)
#
# 53.500904 53.508324
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2350.503589285691
#
# Train set: Avg. loss: 0.024554905, Accuracy: 512/512 (100%)
#
# 53.71188 53.719284
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2339.3186628058647
#
# Train set: Avg. loss: 0.024249369, Accuracy: 512/512 (100%)
#
# 53.921036 53.92845
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2328.4246568643853
#
# Train set: Avg. loss: 0.023950197, Accuracy: 512/512 (100%)
#
# 54.12843 54.135853
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2317.801868662765
# (tensor(44.), tensor(8.5985e+08))
#
# Train set: Avg. loss: 0.023657214, Accuracy: 512/512 (100%)
#
# 54.33409 54.34151
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2307.4707649862607
#
# Train set: Avg. loss: 0.023370232, Accuracy: 512/512 (100%)
#
# 54.538044 54.545464
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2297.3706613240543
#
# Train set: Avg. loss: 0.023089094, Accuracy: 512/512 (100%)
#
# 54.740314 54.74772
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2287.5209032005787
#
# Train set: Avg. loss: 0.022813654, Accuracy: 512/512 (100%)
#
# 54.940907 54.94832
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2277.920097016094
#
# Train set: Avg. loss: 0.022543721, Accuracy: 512/512 (100%)
#
# 55.139854 55.147278
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2268.5263494083515
# (tensor(44.), tensor(1.4085e+09))
#
# Train set: Avg. loss: 0.022279177, Accuracy: 512/512 (100%)
#
# 55.337196 55.344627
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2259.374998022823
#
# Train set: Avg. loss: 0.022019845, Accuracy: 512/512 (100%)
#
# 55.532967 55.540386
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2250.4297737586344
#
# Train set: Avg. loss: 0.021765599, Accuracy: 512/512 (100%)
#
# 55.72716 55.734577
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2241.702603796893
#
# Train set: Avg. loss: 0.021516304, Accuracy: 512/512 (100%)
#
# 55.919796 55.927223
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2233.1475861478034
#
# Train set: Avg. loss: 0.021271795, Accuracy: 512/512 (100%)
#
# 56.110962 56.11835
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2224.797185705563
# (tensor(44.), tensor(2.2626e+09))
#
# Train set: Avg. loss: 0.021032017, Accuracy: 512/512 (100%)
#
# 56.30056 56.307976
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2216.6425297956366
#
# Train set: Avg. loss: 0.020796768, Accuracy: 512/512 (100%)
#
# 56.48874 56.49612
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2208.63754571419
#
# Train set: Avg. loss: 0.020565998, Accuracy: 512/512 (100%)
#
# 56.675407 56.682808
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2200.831416986058
#
# Train set: Avg. loss: 0.020339528, Accuracy: 512/512 (100%)
#
# 56.860683 56.868065
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2193.1918778236723
#
# Train set: Avg. loss: 0.020117285, Accuracy: 512/512 (100%)
#
# 57.04451 57.0519
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2185.700416479931
# (tensor(43.), tensor(3.5690e+09))
#
# Train set: Avg. loss: 0.019899162, Accuracy: 512/512 (100%)
#
# 57.22694 57.234337
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2178.3736783550985
#
# Train set: Avg. loss: 0.019685019, Accuracy: 512/512 (100%)
#
# 57.408028 57.415394
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2171.1836224987774
#
# Train set: Avg. loss: 0.019474795, Accuracy: 512/512 (100%)
#
# 57.587734 57.5951
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2164.164909949523
#
# Train set: Avg. loss: 0.019268380, Accuracy: 512/512 (100%)
#
# 57.766087 57.77346
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2157.270959287525
#
# Train set: Avg. loss: 0.019065674, Accuracy: 512/512 (100%)
#
# 57.943123 57.9505
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2150.5260834076216
# (tensor(43.), tensor(5.5351e+09))
#
# Train set: Avg. loss: 0.018866576, Accuracy: 512/512 (100%)
#
# 58.11887 58.126244
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2143.8971159498474
#
# Train set: Avg. loss: 0.018671010, Accuracy: 512/512 (100%)
#
# 58.29334 58.300694
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2137.41565361625
#
# Train set: Avg. loss: 0.018478889, Accuracy: 512/512 (100%)
#
# 58.46653 58.473877
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2131.0596173523145
#
# Train set: Avg. loss: 0.018290125, Accuracy: 512/512 (100%)
#
# 58.63847 58.645805
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2124.8092952814945
#
# Train set: Avg. loss: 0.018104643, Accuracy: 512/512 (100%)
#
# 58.809174 58.816505
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2118.688154178435
# (tensor(43.), tensor(8.4495e+09))
#
# Train set: Avg. loss: 0.017922360, Accuracy: 512/512 (100%)
#
# 58.978653 58.98598
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2112.6874631382584
#
# Train set: Avg. loss: 0.017743204, Accuracy: 512/512 (100%)
#
# 59.146927 59.15426
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2106.7898097826087
#
# Train set: Avg. loss: 0.017567106, Accuracy: 512/512 (100%)
#
# 59.314003 59.321346
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2101.0122205461826
#
# Train set: Avg. loss: 0.017393976, Accuracy: 512/512 (100%)
#
# 59.479916 59.487263
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2095.326178454161
#
# Train set: Avg. loss: 0.017223755, Accuracy: 512/512 (100%)
#
# 59.644672 59.65202
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2089.7466712537803
# (tensor(43.), tensor(1.2709e+10))
#
# Train set: Avg. loss: 0.017056370, Accuracy: 512/512 (100%)
#
# 59.808292 59.81563
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2084.2551881634167
#
# Train set: Avg. loss: 0.016891755, Accuracy: 512/512 (100%)
#
# 59.9708 59.97812
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2078.8703160026034
# Train set: Avg. loss: 0.016729837, Accuracy: 512/512 (100%)
#
# 60.132217 60.139507
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2073.5834263341244
#
# Train set: Avg. loss: 0.016570602, Accuracy: 512/512 (100%)
#
# 60.29247 60.299786
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2068.392015660139
#
# Train set: Avg. loss: 0.016413951, Accuracy: 512/512 (100%)
#
# 60.45165 60.458977
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2063.2800960571703
# (tensor(43.), tensor(1.8851e+10))
#
# Train set: Avg. loss: 0.016259816, Accuracy: 512/512 (100%)
#
# 60.609787 60.617104
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2058.266948813778
#
# Train set: Avg. loss: 0.016108152, Accuracy: 512/512 (100%)
#
# 60.76688 60.774162
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2053.322703811589
#
# Train set: Avg. loss: 0.015958937, Accuracy: 512/512 (100%)
#
# 60.92286 60.930183
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2048.4655742912087
#
# Train set: Avg. loss: 0.015812056, Accuracy: 512/512 (100%)
#
# 61.07787 61.085175
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2043.6877734803945
#
# Train set: Avg. loss: 0.015667498, Accuracy: 512/512 (100%)
#
# 61.231853 61.239136
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2038.9955314658043
# (tensor(43.), tensor(2.7600e+10))
#
# Train set: Avg. loss: 0.015525221, Accuracy: 512/512 (100%)
#
# 61.38479 61.392094
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2034.3758133140548
#
# Train set: Avg. loss: 0.015385119, Accuracy: 512/512 (100%)
#
# 61.536816 61.54406
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2029.8356735529421
#
# Train set: Avg. loss: 0.015247231, Accuracy: 512/512 (100%)
#
# 61.68775 61.69504
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2025.3631150177523
#
# Train set: Avg. loss: 0.015111418, Accuracy: 512/512 (100%)
#
# 61.837807 61.845047
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2020.9623884329937
#
# Train set: Avg. loss: 0.014977721, Accuracy: 512/512 (100%)
#
# 61.986828 61.994102
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2016.623895975972
# (tensor(43.), tensor(3.9916e+10))
#
# Train set: Avg. loss: 0.014846016, Accuracy: 512/512 (100%)
#
# 62.134975 62.142212
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2012.3609388587495
#
# Train set: Avg. loss: 0.014716329, Accuracy: 512/512 (100%)
#
# 62.28211 62.289383
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2008.163234872328
#
# Train set: Avg. loss: 0.014588553, Accuracy: 512/512 (100%)
#
# 62.42841 62.435623
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 2004.029144877285
#
# Train set: Avg. loss: 0.014462724, Accuracy: 512/512 (100%)
#
# 62.57368 62.580948
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1999.9564756890206
#
# Train set: Avg. loss: 0.014338731, Accuracy: 512/512 (100%)
#
# 62.71814 62.72537
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1995.9479596968133
# (tensor(43.), tensor(5.7065e+10))
#
# Train set: Avg. loss: 0.014216590, Accuracy: 512/512 (100%)
#
# 62.861645 62.868893
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1991.992384866433
#
# Train set: Avg. loss: 0.014096218, Accuracy: 512/512 (100%)
#
# 63.004284 63.011543
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1988.098543809604
#
# Train set: Avg. loss: 0.013977583, Accuracy: 512/512 (100%)
#
# 63.146126 63.153313
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1984.2520121548669
#
# Train set: Avg. loss: 0.013860714, Accuracy: 512/512 (100%)
#
# 63.28698 63.294216
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1980.4812996302358
#
# Train set: Avg. loss: 0.013745504, Accuracy: 512/512 (100%)
#
# 63.427032 63.434273
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1976.747655062388
# (tensor(43.), tensor(8.0697e+10))
#
# Train set: Avg. loss: 0.013631921, Accuracy: 512/512 (100%)
#
# 63.566296 63.57348
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1973.0804422535218
#
# Train set: Avg. loss: 0.013519993, Accuracy: 512/512 (100%)
#
# 63.704636 63.711853
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1969.4538492880322
#
# Train set: Avg. loss: 0.013409635, Accuracy: 512/512 (100%)
#
# 63.84217 63.849403
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1965.8901389322223
#
# Train set: Avg. loss: 0.013300816, Accuracy: 512/512 (100%)
#
# 63.978928 63.98615
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1962.3674244276574
#
# Train set: Avg. loss: 0.013193512, Accuracy: 512/512 (100%)
#
# 64.11491 64.12207
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1958.8914804591986
# (tensor(43.), tensor(1.1295e+11))
#
# Train set: Avg. loss: 0.013087752, Accuracy: 512/512 (100%)
#
# 64.24997 64.25719
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1955.4705481141796
#
# Train set: Avg. loss: 0.012983323, Accuracy: 512/512 (100%)
#
# 64.384575 64.391525
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1952.0956592725713
#
# Train set: Avg. loss: 0.012880535, Accuracy: 512/512 (100%)
#
# 64.51786 64.525085
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1948.7578006119963
#
# Train set: Avg. loss: 0.012779001, Accuracy: 512/512 (100%)
#
# 64.65079 64.657875
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1945.4612020049708
#
# Train set: Avg. loss: 0.012678923, Accuracy: 512/512 (100%)
#
# 64.782745 64.789894
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1942.2268857954423
# (tensor(43.), tensor(1.5656e+11))
#
# Train set: Avg. loss: 0.012580184, Accuracy: 512/512 (100%)
#
# 64.91398 64.92116
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1939.019543105524
#
# Train set: Avg. loss: 0.012482705, Accuracy: 512/512 (100%)
#
# 65.04466 65.05168
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1935.85690661759
#
# Train set: Avg. loss: 0.012386669, Accuracy: 512/512 (100%)
#
# 65.17424 65.18146
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1932.7478804562759
#
# Train set: Avg. loss: 0.012291718, Accuracy: 512/512 (100%)
#
# 65.30363 65.3105
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1929.6696763706027
#
# Train set: Avg. loss: 0.012198253, Accuracy: 512/512 (100%)
#
# 65.431625 65.43883
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1926.6252462419855
# (tensor(43.), tensor(2.1501e+11))
#
# Train set: Avg. loss: 0.012105826, Accuracy: 512/512 (100%)
#
# 65.55946 65.566444
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1923.6258809621243
#
# Train set: Avg. loss: 0.012014765, Accuracy: 512/512 (100%)
#
# 65.686165 65.69333
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1920.6708338761277
#
# Train set: Avg. loss: 0.011924770, Accuracy: 512/512 (100%)
#
# 65.81251 65.819534
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1917.744826849582
#
# Train set: Avg. loss: 0.011836028, Accuracy: 512/512 (100%)
#
# 65.9379 65.94503
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1914.8575926293731
#
# Train set: Avg. loss: 0.011748369, Accuracy: 512/512 (100%)
#
# 66.06279 66.06985
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1911.9974677102875
# (tensor(43.), tensor(2.9273e+11))
#
# Train set: Avg. loss: 0.011661876, Accuracy: 512/512 (100%)
#
# 66.186874 66.19399
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1909.1925190173984
#
# Train set: Avg. loss: 0.011576457, Accuracy: 512/512 (100%)
#
# 66.31039 66.31746
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1906.3956065422083
#
# Train set: Avg. loss: 0.011492150, Accuracy: 512/512 (100%)
#
# 66.43314 66.44025
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1903.6645478739415
#
# Train set: Avg. loss: 0.011408878, Accuracy: 512/512 (100%)
#
# 66.55533 66.562386
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1900.9399706731826
#
# Train set: Avg. loss: 0.011326690, Accuracy: 512/512 (100%)
#
# 66.67676 66.683876
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1898.2582334325978
# (tensor(43.), tensor(3.9523e+11))
#
# Train set: Avg. loss: 0.011245479, Accuracy: 512/512 (100%)
#
# 66.79768 66.80472
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1895.5943579785046
#
# Train set: Avg. loss: 0.011165344, Accuracy: 512/512 (100%)
#
# 66.91777 66.92492
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1892.9862243672153
#
# Train set: Avg. loss: 0.011086112, Accuracy: 512/512 (100%)
#
# 67.03751 67.04448
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1890.3877655035233
#
# Train set: Avg. loss: 0.011007972, Accuracy: 512/512 (100%)
#
# 67.15625 67.16342
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1887.8251899335432
#
# Train set: Avg. loss: 0.010930637, Accuracy: 512/512 (100%)
#
# 67.27488 67.28174
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1885.2994018989662
# (tensor(43.), tensor(5.2946e+11))
#
# Train set: Avg. loss: 0.010854430, Accuracy: 512/512 (100%)
#
# 67.392265 67.39945
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1882.7961577776405
#
# Train set: Avg. loss: 0.010778937, Accuracy: 512/512 (100%)
#
# 67.50975 67.516525
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1880.3267273807824
#
# Train set: Avg. loss: 0.010704588, Accuracy: 512/512 (100%)
#
# 67.62586 67.633026
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1877.8820880348985
#
# Train set: Avg. loss: 0.010630949, Accuracy: 512/512 (100%)
#
# 67.74198 67.74892
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1875.4611527209183
#
# Train set: Avg. loss: 0.010558302, Accuracy: 512/512 (100%)
#
# 67.85713 67.864235
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1873.0825220096942
# (tensor(43.), tensor(7.0387e+11))
#
# Train set: Avg. loss: 0.010486474, Accuracy: 512/512 (100%)
#
# 67.97188 67.978935
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1870.7194004186588
# Train set: Avg. loss: 0.010415461, Accuracy: 512/512 (100%)
#
# 68.086136 68.09308
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1868.3794407025514
#
# Train set: Avg. loss: 0.010345383, Accuracy: 512/512 (100%)
#
# 68.1995 68.20665
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1866.060103278813
#
# Train set: Avg. loss: 0.010275930, Accuracy: 512/512 (100%)
#
# 68.31296 68.31964
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1863.7715697172996
#
# Train set: Avg. loss: 0.010207560, Accuracy: 512/512 (100%)
#
# 68.424934 68.43207
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1861.5193112778754
# (tensor(43.), tensor(9.2913e+11))
#
# Train set: Avg. loss: 0.010139791, Accuracy: 512/512 (100%)
#
# 68.536995 68.543945
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1859.272500616433
#
# Train set: Avg. loss: 0.010072884, Accuracy: 512/512 (100%)
#
# 68.648254 68.65526
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1857.0743113275234
#
# Train set: Avg. loss: 0.010006752, Accuracy: 512/512 (100%)
#
# 68.75892 68.76604
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1854.8720560219292
#
# Train set: Avg. loss: 0.009941239, Accuracy: 512/512 (100%)
#
# 68.86957 68.87625
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1852.694863382283
#
# Train set: Avg. loss: 0.009876702, Accuracy: 512/512 (100%)
#
# 68.97883 68.985954
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1850.5598234078534
# (tensor(43.), tensor(1.2182e+12))
#
# Train set: Avg. loss: 0.009812730, Accuracy: 512/512 (100%)
#
# 69.08817 69.09511
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1848.4281075650754
#
# Train set: Avg. loss: 0.009749532, Accuracy: 512/512 (100%)
#
# 69.1968 69.20375
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1846.3415958378162
#
# Train set: Avg. loss: 0.009687092, Accuracy: 512/512 (100%)
#
# 69.30473 69.31186
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1844.2535602250043
#
# Train set: Avg. loss: 0.009625189, Accuracy: 512/512 (100%)
#
# 69.41275 69.41945
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1842.2029009807686
#
# Train set: Avg. loss: 0.009564186, Accuracy: 512/512 (100%)
#
# 69.51945 69.52653
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1840.1614019214458
# (tensor(44.), tensor(1.5868e+12))
#
# Train set: Avg. loss: 0.009503755, Accuracy: 512/512 (100%)
#
# 69.626045 69.63309
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1838.1451886457157
#
# Train set: Avg. loss: 0.009443909, Accuracy: 512/512 (100%)
#
# 69.732445 69.73915
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1836.152103669703
#
# Train set: Avg. loss: 0.009384913, Accuracy: 512/512 (100%)
#
# 69.83761 69.84473
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1834.1774443246086
#
# Train set: Avg. loss: 0.009326416, Accuracy: 512/512 (100%)
#
# 69.94285 69.94978
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1832.224842086363
#
# Train set: Avg. loss: 0.009268568, Accuracy: 512/512 (100%)
#
# 70.04755 70.05437
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1830.2913268642308
# (tensor(44.), tensor(2.0541e+12))
#
# Train set: Avg. loss: 0.009211451, Accuracy: 512/512 (100%)
#
# 70.151344 70.15845
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1828.3745515001517
#
# Train set: Avg. loss: 0.009154807, Accuracy: 512/512 (100%)
#
# 70.25522 70.26206
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1826.4670804354412
#
# Train set: Avg. loss: 0.009098851, Accuracy: 512/512 (100%)
#
# 70.358315 70.3652
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1824.589983664503
#
# Train set: Avg. loss: 0.009043541, Accuracy: 512/512 (100%)
#
# 70.46074 70.46785
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1822.7304044422892
#
# Train set: Avg. loss: 0.008988688, Accuracy: 512/512 (100%)
#
# 70.56325 70.57002
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1820.8832827099502
# (tensor(44.), tensor(2.6432e+12))
#
# Train set: Avg. loss: 0.008934515, Accuracy: 512/512 (100%)
#
# 70.66486 70.67175
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1819.0565593087197
#
# Train set: Avg. loss: 0.008880940, Accuracy: 512/512 (100%)
#
# 70.76591 70.77301
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1817.2573942846166
#
# Train set: Avg. loss: 0.008827803, Accuracy: 512/512 (100%)
#
# 70.86703 70.87381
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1815.4611752279854
#
# Train set: Avg. loss: 0.008775313, Accuracy: 512/512 (100%)
#
# 70.96731 70.97416
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1813.6868751220957
#
# Train set: Avg. loss: 0.008723413, Accuracy: 512/512 (100%)
#
# 71.06696 71.07406
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1811.916710798344
# (tensor(44.), tensor(3.3818e+12))
#
# Train set: Avg. loss: 0.008671923, Accuracy: 512/512 (100%)
#
# 71.16669 71.17352
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1810.189738589774
#
# Train set: Avg. loss: 0.008621024, Accuracy: 512/512 (100%)
#
# 71.26576 71.27251
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1808.4517553677408
#
# Train set: Avg. loss: 0.008570732, Accuracy: 512/512 (100%)
#
# 71.36401 71.37109
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1806.7371342852405
#
# Train set: Avg. loss: 0.008520839, Accuracy: 512/512 (100%)
#
# 71.46233 71.46922
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1805.0485584224225
#
# Train set: Avg. loss: 0.008471426, Accuracy: 512/512 (100%)
#
# 71.56034 71.56693
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1803.3682023129038
# (tensor(44.), tensor(4.3040e+12))
#
# Train set: Avg. loss: 0.008422690, Accuracy: 512/512 (100%)
#
# 71.65718 71.6642
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1801.7049156743503
#
# Train set: Avg. loss: 0.008374333, Accuracy: 512/512 (100%)
#
# 71.75409 71.76105
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1800.0585729296445
#
# Train set: Avg. loss: 0.008326346, Accuracy: 512/512 (100%)
#
# 71.85106 71.85749
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1798.4161331841012
#
# Train set: Avg. loss: 0.008279081, Accuracy: 512/512 (100%)
#
# 71.946594 71.95351
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1796.8001140190815
#
# Train set: Avg. loss: 0.008232202, Accuracy: 512/512 (100%)
#
# 72.042076 72.0491
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1795.199909105643
# (tensor(44.), tensor(5.4479e+12))
#
# Train set: Avg. loss: 0.008185677, Accuracy: 512/512 (100%)
#
# 72.13763 72.14429
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1793.5967682419907
#
# Train set: Avg. loss: 0.008139706, Accuracy: 512/512 (100%)
#
# 72.23239 72.239075
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1792.0316555448496
#
# Train set: Avg. loss: 0.008094253, Accuracy: 512/512 (100%)
#
# 72.32645 72.33346
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1790.4548115893115
#
# Train set: Avg. loss: 0.008049145, Accuracy: 512/512 (100%)
#
# 72.420555 72.42742
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1788.9117256312668
#
# Train set: Avg. loss: 0.008004376, Accuracy: 512/512 (100%)
#
# 72.51473 72.52101
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1787.36266563047
# (tensor(44.), tensor(6.8631e+12))
#
# Train set: Avg. loss: 0.007960299, Accuracy: 512/512 (100%)
#
# 72.607346 72.61423
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1785.8539058920974
#
# Train set: Avg. loss: 0.007916557, Accuracy: 512/512 (100%)
#
# 72.70001 72.707
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1784.342101596383
#
# Train set: Avg. loss: 0.007873135, Accuracy: 512/512 (100%)
#
# 72.79274 72.79942
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1782.8305434841316
#
# Train set: Avg. loss: 0.007830166, Accuracy: 512/512 (100%)
#
# 72.884926 72.89146
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1781.356166808089
#
# Train set: Avg. loss: 0.007787743, Accuracy: 512/512 (100%)
#
# 72.97614 72.98308
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1779.8744270241452
# (tensor(44.), tensor(8.6016e+12))
#
# Train set: Avg. loss: 0.007745625, Accuracy: 512/512 (100%)
#
# 73.06741 73.07434
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1778.415910821412
#
# Train set: Avg. loss: 0.007703816, Accuracy: 512/512 (100%)
#
# 73.158745 73.16524
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1776.9751416927854
#
# Train set: Avg. loss: 0.007662522, Accuracy: 512/512 (100%)
#
# 73.24914 73.25575
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1775.5375233505113
#
# Train set: Avg. loss: 0.007621665, Accuracy: 512/512 (100%)
#
# 73.33894 73.3459
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1774.099760175769
#
# Train set: Avg. loss: 0.007581105, Accuracy: 512/512 (100%)
#
# 73.42881 73.43567
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1772.694075934104
# (tensor(44.), tensor(1.0733e+13))
#
# Train set: Avg. loss: 0.007540831, Accuracy: 512/512 (100%)
#
# 73.51873 73.5251
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1771.2872377203755
#
# Train set: Avg. loss: 0.007501101, Accuracy: 512/512 (100%)
#
# 73.60751 73.61415
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1769.8942056033245
#
# Train set: Avg. loss: 0.007461746, Accuracy: 512/512 (100%)
#
# 73.69591 73.70286
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1768.533025531167
#
# Train set: Avg. loss: 0.007422664, Accuracy: 512/512 (100%)
#
# 73.78435 73.7912
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1767.1476360745078
#
# Train set: Avg. loss: 0.007383863, Accuracy: 512/512 (100%)
#
# 73.87285 73.879196
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1765.8009172467355
# (tensor(44.), tensor(1.3333e+13))
#
# Train set: Avg. loss: 0.007345579, Accuracy: 512/512 (100%)
#
# 73.960236 73.96681
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1764.4525957879432
# Train set: Avg. loss: 0.007307655, Accuracy: 512/512 (100%)
#
# 74.047195 74.05412
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1763.1211215955973
#
# Train set: Avg. loss: 0.007269997, Accuracy: 512/512 (100%)
#
# 74.13422 74.14107
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1761.7886565904191
#
# Train set: Avg. loss: 0.007232604, Accuracy: 512/512 (100%)
#
# 74.221275 74.22766
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1760.48663329445
#
# Train set: Avg. loss: 0.007195652, Accuracy: 512/512 (100%)
#
# 74.30747 74.31394
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1759.1667934240436
# (tensor(44.), tensor(1.6491e+13))
#
# Train set: Avg. loss: 0.007159103, Accuracy: 512/512 (100%)
#
# 74.393 74.39987
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1757.8800067601826
#
# Train set: Avg. loss: 0.007122809, Accuracy: 512/512 (100%)
#
# 74.47856 74.48545
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1756.5967477114775
#
# Train set: Avg. loss: 0.007086756, Accuracy: 512/512 (100%)
#
# 74.564186 74.570724
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1755.3329742552974
#
# Train set: Avg. loss: 0.007051034, Accuracy: 512/512 (100%)
#
# 74.649445 74.655655
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1754.0550390875555
#
# Train set: Avg. loss: 0.007015802, Accuracy: 512/512 (100%)
#
# 74.73351 74.74025
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1752.7826566493818
# (tensor(44.), tensor(2.0311e+13))
#
# Train set: Avg. loss: 0.006980808, Accuracy: 512/512 (100%)
#
# 74.81763 74.82451
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1751.555451602714
#
# Train set: Avg. loss: 0.006946045, Accuracy: 512/512 (100%)
#
# 74.90179 74.908485
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1750.329864219519
#
# Train set: Avg. loss: 0.006911518, Accuracy: 512/512 (100%)
#
# 74.986 74.99213
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1749.0995764913605
#
# Train set: Avg. loss: 0.006877475, Accuracy: 512/512 (100%)
#
# 75.068954 75.07544
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1747.8642587264242
#
# Train set: Avg. loss: 0.006843730, Accuracy: 512/512 (100%)
#
# 75.1516 75.15843
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1746.6707264196552
# (tensor(44.), tensor(2.4919e+13))
#
# Train set: Avg. loss: 0.006810206, Accuracy: 512/512 (100%)
#
# 75.2343 75.241135
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1745.4576710454198
#
# Train set: Avg. loss: 0.006776900, Accuracy: 512/512 (100%)
#
# 75.31705 75.32352
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1744.268950967893
#
# Train set: Avg. loss: 0.006743871, Accuracy: 512/512 (100%)
#
# 75.39955 75.4056
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1743.0883051053265
#
# Train set: Avg. loss: 0.006711319, Accuracy: 512/512 (100%)
#
# 75.48073 75.48736
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1741.9242578254489
#
# Train set: Avg. loss: 0.006678986, Accuracy: 512/512 (100%)
#
# 75.56194 75.56879
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1740.7614043061233
# (tensor(44.), tensor(3.0455e+13))
#
# Train set: Avg. loss: 0.006646859, Accuracy: 512/512 (100%)
#
# 75.64321 75.64995
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1739.6000886153138
#
# Train set: Avg. loss: 0.006614935, Accuracy: 512/512 (100%)
#
# 75.72452 75.730835
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1738.4445178773865
#
# Train set: Avg. loss: 0.006583340, Accuracy: 512/512 (100%)
#
# 75.80525 75.81137
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1737.3054209843244
#
# Train set: Avg. loss: 0.006552141, Accuracy: 512/512 (100%)
#
# 75.88499 75.891624
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1736.186643598321
#
# Train set: Avg. loss: 0.006521138, Accuracy: 512/512 (100%)
#
# 75.96476 75.9716
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1735.0628437784817
# (tensor(44.), tensor(3.7085e+13))
#
# Train set: Avg. loss: 0.006490338, Accuracy: 512/512 (100%)
#
# 76.04458 76.051285
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1733.9273515809143
#
# Train set: Avg. loss: 0.006459731, Accuracy: 512/512 (100%)
#
# 76.124435 76.13066
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1732.8293797597973
#
# Train set: Avg. loss: 0.006429441, Accuracy: 512/512 (100%)
#
# 76.2037 76.209755
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1731.7429170395699
#
# Train set: Avg. loss: 0.006399522, Accuracy: 512/512 (100%)
#
# 76.281975 76.28858
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1730.6435338076692
#
# Train set: Avg. loss: 0.006369791, Accuracy: 512/512 (100%)
#
# 76.36029 76.36713
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1729.5602148770315
# (tensor(44.), tensor(4.4996e+13))
#
# Train set: Avg. loss: 0.006340252, Accuracy: 512/512 (100%)
#
# 76.43865 76.44537
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1728.4806219102607
#
# Train set: Avg. loss: 0.006310900, Accuracy: 512/512 (100%)
#
# 76.517044 76.52333
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1727.4084541439004
#
# Train set: Avg. loss: 0.006281779, Accuracy: 512/512 (100%)
#
# 76.59516 76.60105
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1726.352388463987
#
# Train set: Avg. loss: 0.006253086, Accuracy: 512/512 (100%)
#
# 76.671974 76.67845
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1725.2873434341943
#
# Train set: Avg. loss: 0.006224570, Accuracy: 512/512 (100%)
#
# 76.74882 76.755585
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1724.2609292542054
# (tensor(44.), tensor(5.4410e+13))
#
# Train set: Avg. loss: 0.006196231, Accuracy: 512/512 (100%)
#
# 76.8257 76.83245
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1723.2192666968135
#
# Train set: Avg. loss: 0.006168063, Accuracy: 512/512 (100%)
#
# 76.90262 76.90906
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1722.1742387789764
#
# Train set: Avg. loss: 0.006140066, Accuracy: 512/512 (100%)
#
# 76.97958 76.985405
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1721.1513859275053
#
# Train set: Avg. loss: 0.006112477, Accuracy: 512/512 (100%)
#
# 77.055244 77.06146
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1720.1251697240841
#
# Train set: Avg. loss: 0.006085115, Accuracy: 512/512 (100%)
#
# 77.1306 77.13724
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1719.1238753511648
# (tensor(44.), tensor(6.5573e+13))
#
# Train set: Avg. loss: 0.006057921, Accuracy: 512/512 (100%)
#
# 77.206 77.21277
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1718.111361829952
#
# Train set: Avg. loss: 0.006030883, Accuracy: 512/512 (100%)
#
# 77.28143 77.288055
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1717.0995262201186
#
# Train set: Avg. loss: 0.006004011, Accuracy: 512/512 (100%)
#
# 77.35691 77.36308
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1716.1216656510178
#
# Train set: Avg. loss: 0.005977353, Accuracy: 512/512 (100%)
#
# 77.43211 77.43785
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1715.133939119797
#
# Train set: Avg. loss: 0.005951089, Accuracy: 512/512 (100%)
#
# 77.50598 77.51235
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1714.1718165177404
# (tensor(44.), tensor(7.8771e+13))
#
# Train set: Avg. loss: 0.005924981, Accuracy: 512/512 (100%)
#
# 77.57988 77.58659
# l2 norm: 0.0
# l1 norm: 0.0
# Rbeta: 1713.186237645346
#
# ...
#
# 69.835365 69.8526
# l2 norm: 365.66221653688956
# l1 norm: 292.373032518411
# Rbeta: 897.2189934815405
#
# Train set: Avg. loss: 0.000772634, Accuracy: 512/512 (100%)
#
# 69.849525 69.86697
# l2 norm: 365.6432663104166
# l1 norm: 292.3585612203432
# Rbeta: 897.1561720173303
# (tensor(54.), tensor(4.0781e+09))
#
# Train set: Avg. loss: 0.000771568, Accuracy: 512/512 (100%)
#
# 69.86359 69.88132
# l2 norm: 365.62360907339774
# l1 norm: 292.3435219365519
# Rbeta: 897.0923439260855
#
# Train set: Avg. loss: 0.000770503, Accuracy: 512/512 (100%)
#
# 69.877655 69.89565
# l2 norm: 365.6042050063305
# l1 norm: 292.3286866281185
# Rbeta: 897.0292371353678
#
# Train set: Avg. loss: 0.000769439, Accuracy: 512/512 (100%)
#
# 69.89173 69.90997
# l2 norm: 365.5844383143995
# l1 norm: 292.313558593496
# Rbeta: 896.9651972725638
#
# Train set: Avg. loss: 0.000768379, Accuracy: 512/512 (100%)
#
# 69.9058 69.924286
# l2 norm: 365.5650540853243
# l1 norm: 292.29874307874206
# Rbeta: 896.9022212477364
#
# Train set: Avg. loss: 0.000767320, Accuracy: 512/512 (100%)
#
# 69.919876 69.93855
# l2 norm: 365.5456979153007
# l1 norm: 292.28395581475996
# Rbeta: 896.8392553180714
# (tensor(54.), tensor(4.1808e+09))
#
# Train set: Avg. loss: 0.000766264, Accuracy: 512/512 (100%)
#
# 69.93395 69.95283
# l2 norm: 365.52700462405113
# l1 norm: 292.2696977907126
# Rbeta: 896.7780370818642
#
# Train set: Avg. loss: 0.000765209, Accuracy: 512/512 (100%)
#
# 69.94803 69.96708
# l2 norm: 365.5083785174568
# l1 norm: 292.2554920926854
# Rbeta: 896.7169133331099
#
# Train set: Avg. loss: 0.000764157, Accuracy: 512/512 (100%)
#
# 69.9621 69.981316
# l2 norm: 365.4902954676795
# l1 norm: 292.24172430978035
# Rbeta: 896.6572780047507
#
# Train set: Avg. loss: 0.000763107, Accuracy: 512/512 (100%)
#
# 69.97618 69.99553
# l2 norm: 365.4719067214244
# l1 norm: 292.227713815843
# Rbeta: 896.5968801895108
#
# Train set: Avg. loss: 0.000762059, Accuracy: 512/512 (100%)
#
# 69.99026 70.00972
# l2 norm: 365.4540424659756
# l1 norm: 292.21411357370886
# Rbeta: 896.5376883122609
# (tensor(54.), tensor(4.2852e+09))
#
# Train set: Avg. loss: 0.000761013, Accuracy: 512/512 (100%)
#
# 70.00434 70.023895
# l2 norm: 365.4370053771817
# l1 norm: 292.20116949862137
# Rbeta: 896.4805806996435
#
# Train set: Avg. loss: 0.000759968, Accuracy: 512/512 (100%)
#
# 70.018425 70.038055
# l2 norm: 365.41866392097273
# l1 norm: 292.1871801801225
# Rbeta: 896.4203400796866
#
# Train set: Avg. loss: 0.000758926, Accuracy: 512/512 (100%)
#
# 70.03251 70.0522
# l2 norm: 365.40077185647294
# l1 norm: 292.1735445942922
# Rbeta: 896.3611331100533
#
# Train set: Avg. loss: 0.000757886, Accuracy: 512/512 (100%)
#
# 70.04659 70.06633
# l2 norm: 365.3826630354789
# l1 norm: 292.15973650217313
# Rbeta: 896.3013354032323
#
# Train set: Avg. loss: 0.000756848, Accuracy: 512/512 (100%)
#
# 70.060684 70.080444
# l2 norm: 365.3647734202916
# l1 norm: 292.14609639074547
# Rbeta: 896.2422651828138
# (tensor(54.), tensor(4.3922e+09))
#
# Train set: Avg. loss: 0.000755812, Accuracy: 512/512 (100%)
#
# 70.07477 70.09454
# l2 norm: 365.34637828257564
# l1 norm: 292.1320468527214
# Rbeta: 896.181921456207
#
# Train set: Avg. loss: 0.000754778, Accuracy: 512/512 (100%)
#
# 70.08886 70.10862
# l2 norm: 365.32768734052047
# l1 norm: 292.1177634987097
# Rbeta: 896.1209151154752
#
# Train set: Avg. loss: 0.000753746, Accuracy: 512/512 (100%)
#
# 70.10295 70.122665
# l2 norm: 365.3089508215524
# l1 norm: 292.10344824535525
# Rbeta: 896.0597465729724
#
# Train set: Avg. loss: 0.000752717, Accuracy: 512/512 (100%)
#
# 70.11705 70.1367
# l2 norm: 365.2912532350083
# l1 norm: 292.0899647708415
# Rbeta: 896.0012550511668
#
# Train set: Avg. loss: 0.000751689, Accuracy: 512/512 (100%)
#
# 70.131134 70.15073
# l2 norm: 365.27328794110224
# l1 norm: 292.0762625985244
# Rbeta: 895.9420028510925
# (tensor(54.), tensor(4.5021e+09))
#
# Train set: Avg. loss: 0.000750663, Accuracy: 512/512 (100%)
#
# 70.14523 70.164734
# l2 norm: 365.25491995083013
# l1 norm: 292.0622250231086
# Rbeta: 895.881844602498
#
# Train set: Avg. loss: 0.000749640, Accuracy: 512/512 (100%)
#
# 70.159325 70.17872
# l2 norm: 365.23702799357386
# l1 norm: 292.048555520473
# Rbeta: 895.8228018641021
#
# Train set: Avg. loss: 0.000748618, Accuracy: 512/512 (100%)
#
# 70.17343 70.192696
# l2 norm: 365.2191991279151
# l1 norm: 292.03492547141207
# Rbeta: 895.7640460667799
#
# Train set: Avg. loss: 0.000747598, Accuracy: 512/512 (100%)
#
# 70.18753 70.20664
# l2 norm: 365.2011490851661
# l1 norm: 292.0211182872672
# Rbeta: 895.7047010057945
#
# Train set: Avg. loss: 0.000746581, Accuracy: 512/512 (100%)
#
# 70.20161 70.22058
# l2 norm: 365.18369661271686
# l1 norm: 292.0077926167929
# Rbeta: 895.6467251100102
# (tensor(54.), tensor(4.6145e+09))
#
# Train set: Avg. loss: 0.000745572, Accuracy: 512/512 (100%)
#
# 70.215515 70.234505
# l2 norm: 365.1663442901595
# l1 norm: 291.9945417764883
# Rbeta: 895.5879526486547
#
# Train set: Avg. loss: 0.000744564, Accuracy: 512/512 (100%)
#
# 70.22943 70.248405
# l2 norm: 365.1492371146278
# l1 norm: 291.9814877888433
# Rbeta: 895.5298917372379
#
# Train set: Avg. loss: 0.000743558, Accuracy: 512/512 (100%)
#
# 70.243355 70.2623
# l2 norm: 365.1324272878881
# l1 norm: 291.96866770585825
# Rbeta: 895.4724322287383
#
# Train set: Avg. loss: 0.000742554, Accuracy: 512/512 (100%)
#
# 70.25727 70.276184
# l2 norm: 365.1161848695597
# l1 norm: 291.9562978652713
# Rbeta: 895.4164480591354
#
# Train set: Avg. loss: 0.000741552, Accuracy: 512/512 (100%)
#
# 70.27119 70.290054
# l2 norm: 365.09988348150256
# l1 norm: 291.94388130724036
# Rbeta: 895.3604080446748
# (tensor(54.), tensor(4.7282e+09))
#
# Train set: Avg. loss: 0.000740551, Accuracy: 512/512 (100%)
#
# 70.28511 70.3039
# l2 norm: 365.08355874328726
# l1 norm: 291.93144439414675
# Rbeta: 895.3042028608681
#
# Train set: Avg. loss: 0.000739552, Accuracy: 512/512 (100%)
#
# 70.299034 70.31774
# l2 norm: 365.06782168370916
# l1 norm: 291.9194783194894
# Rbeta: 895.2494585555061
#
# Train set: Avg. loss: 0.000738556, Accuracy: 512/512 (100%)
#
# 70.31296 70.33156
# l2 norm: 365.0516980738894
# l1 norm: 291.9072013738022
# Rbeta: 895.1937963791978
#
# Train set: Avg. loss: 0.000737561, Accuracy: 512/512 (100%)
#
# 70.32689 70.34537
# l2 norm: 365.035495056315
# l1 norm: 291.89485523765154
# Rbeta: 895.1379933183878
#
# Train set: Avg. loss: 0.000736567, Accuracy: 512/512 (100%)
#
# 70.340805 70.35916
# l2 norm: 365.01953231081734
# l1 norm: 291.88269913699276
# Rbeta: 895.0826190230398
# (tensor(54.), tensor(4.8444e+09))
# Train set: Avg. loss: 0.000735576, Accuracy: 512/512 (100%)
#
# 70.35474 70.372955
# l2 norm: 365.0028636305535
# l1 norm: 291.86998091514806
# Rbeta: 895.0256739719725
#
# Train set: Avg. loss: 0.000734586, Accuracy: 512/512 (100%)
#
# 70.36867 70.38673
# l2 norm: 364.98626005349143
# l1 norm: 291.8573176679832
# Rbeta: 894.9689159602686
#
# Train set: Avg. loss: 0.000733598, Accuracy: 512/512 (100%)
#
# 70.3826 70.40049
# l2 norm: 364.97009497539733
# l1 norm: 291.84500485736635
# Rbeta: 894.9130954764787
#
# Train set: Avg. loss: 0.000732612, Accuracy: 512/512 (100%)
#
# 70.39653 70.41423
# l2 norm: 364.9532113559946
# l1 norm: 291.8321169591085
# Rbeta: 894.8556090868423
#
# Train set: Avg. loss: 0.000731627, Accuracy: 512/512 (100%)
#
# 70.41047 70.42796
# l2 norm: 364.93637545503174
# l1 norm: 291.81926827656696
# Rbeta: 894.7983220994887
# (tensor(54.), tensor(4.9641e+09))
#
# Train set: Avg. loss: 0.000730645, Accuracy: 512/512 (100%)
#
# 70.42441 70.44167
# l2 norm: 364.91880655937445
# l1 norm: 291.8058325991492
# Rbeta: 894.7391774129676
#
# Train set: Avg. loss: 0.000729664, Accuracy: 512/512 (100%)
#
# 70.43834 70.45537
# l2 norm: 364.9012008638783
# l1 norm: 291.7923642349891
# Rbeta: 894.6798699654476
#
# Train set: Avg. loss: 0.000728686, Accuracy: 512/512 (100%)
#
# 70.45227 70.46904
# l2 norm: 364.8836719723669
# l1 norm: 291.77895235759576
# Rbeta: 894.620750641588
#
# Train set: Avg. loss: 0.000727709, Accuracy: 512/512 (100%)
#
# 70.46622 70.4827
# l2 norm: 364.86620486070143
# l1 norm: 291.76558799573434
# Rbeta: 894.5618314846766
#
# Train set: Avg. loss: 0.000726734, Accuracy: 512/512 (100%)
#
# 70.480156 70.49635
# l2 norm: 364.8489832827379
# l1 norm: 291.75241959581876
# Rbeta: 894.5035229308425
# (tensor(54.), tensor(5.0865e+09))
#
# Train set: Avg. loss: 0.000725761, Accuracy: 512/512 (100%)
#
# 70.494095 70.50999
# l2 norm: 364.8319542968471
# l1 norm: 291.73940297981494
# Rbeta: 894.4457520694154
#
# Train set: Avg. loss: 0.000724789, Accuracy: 512/512 (100%)
#
# 70.50804 70.523605
# l2 norm: 364.81478447805574
# l1 norm: 291.72627842224733
# Rbeta: 894.3875641745775
#
# Train set: Avg. loss: 0.000723819, Accuracy: 512/512 (100%)
#
# 70.52199 70.53722
# l2 norm: 364.79734940154884
# l1 norm: 291.7129411599386
# Rbeta: 894.3288996313026
#
# Train set: Avg. loss: 0.000722852, Accuracy: 512/512 (100%)
#
# 70.535934 70.5508
# l2 norm: 364.78093275225655
# l1 norm: 291.70041625305714
# Rbeta: 894.2726906517221
#
# Train set: Avg. loss: 0.000721886, Accuracy: 512/512 (100%)
#
# 70.54988 70.56435
# l2 norm: 364.7636367703443
# l1 norm: 291.68718203808567
# Rbeta: 894.214290786303
# (tensor(54.), tensor(5.2117e+09))
#
# Train set: Avg. loss: 0.000720922, Accuracy: 512/512 (100%)
#
# 70.56383 70.57789
# l2 norm: 364.74669528409856
# l1 norm: 291.67422933688886
# Rbeta: 894.1568498028521
#
# Train set: Avg. loss: 0.000719960, Accuracy: 512/512 (100%)
#
# 70.57778 70.591415
# l2 norm: 364.72991658822156
# l1 norm: 291.6614105752676
# Rbeta: 894.099751580862
#
# Train set: Avg. loss: 0.000719000, Accuracy: 512/512 (100%)
#
# 70.59173 70.60493
# l2 norm: 364.7126425529433
# l1 norm: 291.64819509593303
# Rbeta: 894.041501887899
#
# Train set: Avg. loss: 0.000718042, Accuracy: 512/512 (100%)
#
# 70.60568 70.61842
# l2 norm: 364.6956612953869
# l1 norm: 291.63521976506394
# Rbeta: 893.9839447946794
#
# Train set: Avg. loss: 0.000717096, Accuracy: 512/512 (100%)
#
# 70.61932 70.631905
# l2 norm: 364.6766937577328
# l1 norm: 291.6206616650266
# Rbeta: 893.9243773056662
# (tensor(54.), tensor(5.3393e+09))
#
# Train set: Avg. loss: 0.000716157, Accuracy: 512/512 (100%)
#
# 70.63286 70.64537
# l2 norm: 364.6572169519259
# l1 norm: 291.6056954656836
# Rbeta: 893.8645861852838
#
# Train set: Avg. loss: 0.000715221, Accuracy: 512/512 (100%)
#
# 70.64633 70.65883
# l2 norm: 364.6373635347132
# l1 norm: 291.5904242684266
# Rbeta: 893.804680310842
#
# Train set: Avg. loss: 0.000714291, Accuracy: 512/512 (100%)
#
# 70.65972 70.67226
# l2 norm: 364.61758628449473
# l1 norm: 291.575214055229
# Rbeta: 893.7454650650546
#
# Train set: Avg. loss: 0.000713361, Accuracy: 512/512 (100%)
#
# 70.67311 70.68568
# l2 norm: 364.59713846375894
# l1 norm: 291.55947657140655
# Rbeta: 893.6847769562957
#
# Train set: Avg. loss: 0.000712434, Accuracy: 512/512 (100%)
#
# 70.68651 70.69908
# l2 norm: 364.57707328259875
# l1 norm: 291.54404086684724
# Rbeta: 893.6249371920409
# (tensor(54.), tensor(5.4679e+09))
#
# Train set: Avg. loss: 0.000711509, Accuracy: 512/512 (100%)
#
# 70.69991 70.71246
# l2 norm: 364.55795388140274
# l1 norm: 291.5293598335679
# Rbeta: 893.5674839445451
#
# Train set: Avg. loss: 0.000710585, Accuracy: 512/512 (100%)
#
# 70.7133 70.72583
# l2 norm: 364.5389108937471
# l1 norm: 291.51474869263825
# Rbeta: 893.5100229971185
#
# Train set: Avg. loss: 0.000709663, Accuracy: 512/512 (100%)
#
# 70.7267 70.73918
# l2 norm: 364.5195527202593
# l1 norm: 291.4998853589684
# Rbeta: 893.4519184962595
#
# Train set: Avg. loss: 0.000708743, Accuracy: 512/512 (100%)
#
# 70.740105 70.75252
# l2 norm: 364.50100933382043
# l1 norm: 291.48567162040126
# Rbeta: 893.3957645360384
#
# Train set: Avg. loss: 0.000707824, Accuracy: 512/512 (100%)
#
# 70.75351 70.76584
# l2 norm: 364.48231357862016
# l1 norm: 291.47133124674735
# Rbeta: 893.3393027229665
# (tensor(54.), tensor(5.5988e+09))
#
# Train set: Avg. loss: 0.000706910, Accuracy: 512/512 (100%)
#
# 70.766815 70.77915
# l2 norm: 364.46348635129533
# l1 norm: 291.4568787063598
# Rbeta: 893.2818469844625
#
# Train set: Avg. loss: 0.000706009, Accuracy: 512/512 (100%)
#
# 70.77973 70.79245
# l2 norm: 364.44703585750307
# l1 norm: 291.4443257911848
# Rbeta: 893.2277955876516
#
# Train set: Avg. loss: 0.000705110, Accuracy: 512/512 (100%)
#
# 70.79265 70.80575
# l2 norm: 364.42963660784983
# l1 norm: 291.4310140003155
# Rbeta: 893.1715040292086
#
# Train set: Avg. loss: 0.000704213, Accuracy: 512/512 (100%)
#
# 70.805565 70.819016
# l2 norm: 364.4132517926196
# l1 norm: 291.4185192695259
# Rbeta: 893.1175657359107
#
# Train set: Avg. loss: 0.000703317, Accuracy: 512/512 (100%)
#
# 70.81849 70.83229
# l2 norm: 364.39588916658835
# l1 norm: 291.40524795904196
# Rbeta: 893.0614970815393
# (tensor(54.), tensor(5.7292e+09))
#
# Train set: Avg. loss: 0.000702422, Accuracy: 512/512 (100%)
#
# 70.831406 70.845535
# l2 norm: 364.37953324367464
# l1 norm: 291.39277725866873
# Rbeta: 893.0075877357184
#
# Train set: Avg. loss: 0.000701530, Accuracy: 512/512 (100%)
#
# 70.84433 70.85878
# l2 norm: 364.36308071229666
# l1 norm: 291.3802243621586
# Rbeta: 892.9536332502248
#
# Train set: Avg. loss: 0.000700639, Accuracy: 512/512 (100%)
#
# 70.857254 70.87201
# l2 norm: 364.3464393608857
# l1 norm: 291.3675216830832
# Rbeta: 892.8991899564247
#
# Train set: Avg. loss: 0.000699749, Accuracy: 512/512 (100%)
#
# 70.87018 70.88522
# l2 norm: 364.3299069056231
# l1 norm: 291.35490263215513
# Rbeta: 892.8450124704897
#
# Train set: Avg. loss: 0.000698860, Accuracy: 512/512 (100%)
#
# 70.8831 70.89843
# l2 norm: 364.3134208028449
# l1 norm: 291.3423211316601
# Rbeta: 892.7909329915852
# (tensor(54.), tensor(5.8619e+09))
#
# Train set: Avg. loss: 0.000697974, Accuracy: 512/512 (100%)
#
# 70.896034 70.91162
# l2 norm: 364.2972425662734
# l1 norm: 291.3299772895451
# Rbeta: 892.7377174515257
#
# Train set: Avg. loss: 0.000697089, Accuracy: 512/512 (100%)
#
# 70.90896 70.924805
# l2 norm: 364.28049008858255
# l1 norm: 291.3171753912614
# Rbeta: 892.6831883136693
#
# Train set: Avg. loss: 0.000696205, Accuracy: 512/512 (100%)
#
# 70.92189 70.93798
# l2 norm: 364.2641105927135
# l1 norm: 291.30467383848304
# Rbeta: 892.6294982363166
#
# Train set: Avg. loss: 0.000695323, Accuracy: 512/512 (100%)
#
# 70.93482 70.951126
# l2 norm: 364.24731145683904
# l1 norm: 291.29184094700383
# Rbeta: 892.5749139887778
#
# Train set: Avg. loss: 0.000694445, Accuracy: 512/512 (100%)
#
# 70.947685 70.964264
# l2 norm: 364.23184196382016
# l1 norm: 291.28006851633086
# Rbeta: 892.5231264751131
# (tensor(54.), tensor(5.9973e+09))
#
# Train set: Avg. loss: 0.000693571, Accuracy: 512/512 (100%)
#
# 70.96043 70.977394
# l2 norm: 364.2165244712154
# l1 norm: 291.2684082379181
# Rbeta: 892.4709185484745
#
# Train set: Avg. loss: 0.000692700, Accuracy: 512/512 (100%)
#
# 70.97317 70.99049
# l2 norm: 364.20106385758385
# l1 norm: 291.2566387132081
# Rbeta: 892.4182931230727
#
# Train set: Avg. loss: 0.000691830, Accuracy: 512/512 (100%)
#
# 70.985916 71.00357
# l2 norm: 364.1858380487333
# l1 norm: 291.245053895711
# Rbeta: 892.3664451784929
#
# Train set: Avg. loss: 0.000690963, Accuracy: 512/512 (100%)
#
# 70.998665 71.01665
# l2 norm: 364.17027764670524
# l1 norm: 291.23319922150597
# Rbeta: 892.3138702123206
#
# Train set: Avg. loss: 0.000690096, Accuracy: 512/512 (100%)
#
# 71.01141 71.02969
# l2 norm: 364.1555040396963
# l1 norm: 291.22197737969327
# Rbeta: 892.26303748917
# (tensor(54.), tensor(6.1340e+09))
# Train set: Avg. loss: 0.000689231, Accuracy: 512/512 (100%)
#
# 71.02417 71.04273
# l2 norm: 364.1405443250071
# l1 norm: 291.2106061040591
# Rbeta: 892.2118115302209
#
# Train set: Avg. loss: 0.000688368, Accuracy: 512/512 (100%)
#
# 71.03691 71.05576
# l2 norm: 364.1252640237292
# l1 norm: 291.19897772073875
# Rbeta: 892.1598588064509
#
# Train set: Avg. loss: 0.000687505, Accuracy: 512/512 (100%)
#
# 71.04967 71.06879
# l2 norm: 364.109659028895
# l1 norm: 291.18709245466874
# Rbeta: 892.1070841889693
#
# Train set: Avg. loss: 0.000686645, Accuracy: 512/512 (100%)
#
# 71.062416 71.08179
# l2 norm: 364.0934435866066
# l1 norm: 291.1747192735333
# Rbeta: 892.0527252810267
#
# Train set: Avg. loss: 0.000685786, Accuracy: 512/512 (100%)
#
# 71.07517 71.09479
# l2 norm: 364.07771357809406
# l1 norm: 291.162726852697
# Rbeta: 891.9997393427604
# (tensor(54.), tensor(6.2735e+09))
# After training:
#
# Train set: Avg. loss: 0.000685786, Accuracy: 512/512 (100%)
#
# tensor(54.) tensor(6.2735e+09)
# 71.07517 71.09479
# l2 norm: 364.07771357809406
# l1 norm: 291.162726852697
# Rbeta: 891.9997393427604
# Time domain:
# Frequency domain:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-344667686efd> in <module>
#      27     for i in range(len(pairs)):
#      28         beta = betas[i]
# ---> 29         beta = beta_array[j]
#      30         name = str(pairs[i]) + "nonlinear" + ".csv"
#      31         print(str(pairs[i]))
#
# NameError: name 'beta_array' is not defined

# %%
print(num_samples)
# Out:
# 128

# %%
print(rbetas)
# Out:
# [1497.0122899364396, 1497.0787712973827, 890.1108245881242, 891.9997393427604]
